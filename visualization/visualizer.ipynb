# %%
from visualization.lr_visualizer import visualize_data_and_lr_decision_boundary
# Out:
# /home/cthfvrl/diploma/Sandbox/pairwise-similarities

# %%
from visualization.lr_visualizer import visualize_error
from similarities.lcs_similarity import LCSSimilarity
visualize_error('filtered.csv', LCSSimilarity(vectorized=False))

# %%
from visualization.lr_visualizer import visualize_error
from similarities.lcs_similarity import LCSSimilarity
visualize_error('filtered.csv', LCSSimilarity(vectorized=False))

# %%
from similarities.lcs_similarity import LCSSimilarity
visualize_data_and_lr_decision_boundary('filtered.csv', LCSSimilarity(vectorized=False))
visualize_data_and_lr_decision_boundary('filtered.csv', LCSSimilarity(vectorized=True))
# Out:
# Precision: 0.8602150537634409
# Recall: 0.7476635514018691
# F1 score: 0.7999999999999999
# Precision: 0.88
# Recall: 0.822429906542056
# F1 score: 0.8502415458937198

# %%
from similarities.cos_similarity import COSSimilarity
visualize_data_and_lr_decision_boundary('filtered.csv', COSSimilarity())
visualize_data_and_lr_decision_boundary('filtered.csv', COSSimilarity(vectorized=True))
# Out:
# Precision: 0.7802197802197802
# Recall: 0.6635514018691588
# F1 score: 0.7171717171717171
# Precision: 0.8118811881188119
# Recall: 0.7663551401869159
# F1 score: 0.7884615384615384

# %%
from similarities.levenshtein_similarity import LevenshteinSimilarity
visualize_data_and_lr_decision_boundary('filtered.csv', LevenshteinSimilarity())
visualize_data_and_lr_decision_boundary('filtered.csv', LevenshteinSimilarity(vectorized=True))
# Out:
# Precision: 0.7924528301886793
# Recall: 0.7850467289719626
# F1 score: 0.7887323943661972
# Precision: 0.7904761904761904
# Recall: 0.7757009345794392
# F1 score: 0.7830188679245284

# %%
from similarities.lsh_similarity import LSHSimilarity
hist_file('filtered.csv', LSHSimilarity())
hist_file('filtered.csv', LSHSimilarity(vectorized=True))
# Out:
# Precision: 0.7604166666666666
# Recall: 0.6822429906542056
# F1 score: 0.7192118226600985
# Precision: 0.7888888888888889
# Recall: 0.6635514018691588
# F1 score: 0.7208121827411167
